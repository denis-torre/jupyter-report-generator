# %%
import sys
sys.path.append('../scripts/')
import Dataset

# %%
reload(Dataset)
# Load dataset
link = 'https://s3.amazonaws.com/mssm-seq-series-platform/GSE16256_GPL11154_series_matrix.txt.gz'
rnaseqDataset = Dataset.Dataset(link)
# rnaseqDataset.plot_pca()
net = rnaseqDataset.plot_clustergram()
# Out:
#             polyA RNA sequencing of STL001 Left Ventricle Cells; polyA-RNA-seq_STL001LV_r1a (GSM1010938)  \
# ID_REF
# MT-CO1                                              -0.448984
# MT-ND4                                              -0.692931
# MT-CO3                                              -0.592769
# MT-CO2                                              -0.577994
# AC010970.2                                           2.314289
#
#             polyA RNA sequencing of STL001 Small Bowel Cells; polyA-RNA-seq_STL001SB_r1a (GSM1010940)  \
# ID_REF
# MT-CO1                                              -0.470034
# MT-ND4                                              -0.646741
# MT-CO3                                              -0.436988
# MT-CO2                                              -0.339511
# AC010970.2                                           3.147466
#
#             polyA RNA sequencing of STL001 Sigmoid Colon Cells; polyA-RNA-seq_STL001SG_r1a (GSM1010942)  \
# ID_REF
# ...

# %%
net.widget()
